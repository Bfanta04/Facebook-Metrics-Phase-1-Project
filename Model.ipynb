# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
import sklearn as sk
import statsmodels.api as sm
import os

# %%
df_encoded= pd.read_csv("/Users/sa19/class-projects/TKH-26-labs/Phase_1/datasets/dataset_Facebook.csv", sep=";")
print(df_encoded)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df_encoded.dropna()
df_encoded = pd.get_dummies(df_encoded, columns= ["Type"], drop_first = True, dtype=float)
df_encoded
# Out:
#      Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# 0              139441         2          12             4          3   0.0
# 1              139441         2          12             3         10   0.0
# 2              139441         3          12             3          3   0.0
# 3              139441         2          12             2         10   1.0
# 4              139441         2          12             2          3   0.0
# ..                ...       ...         ...           ...        ...   ...
# 495             85093         3           1             7          2   0.0
# 496             81370         2           1             5          8   0.0
# 497             81370         1           1             5          2   0.0
# 498             81370         3           1             4         11   0.0
# 499             81370         2           1             4          4   NaN
#
#      Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
df_encoded.isna().sum()
df_encoded = df_encoded.dropna(inplace=True)

# %%
#X is all of the data that is not our target
#Y is our target: Total Interact

X = df_encoded.drop('Lifetime Engaged Users', axis = 1)
Y = df_encoded['Lifetime Engaged Users']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       1 #X is all of the data that is not our target
#       2 #Y is our target: Total Interact
# ----> 4 X = df_encoded.drop('Lifetime Engaged Users', axis = 1)
#       5 Y = df_encoded['Lifetime Engaged Users']
#       7 from sklearn.model_selection import train_test_split
#
# AttributeError: 'NoneType' object has no attribute 'drop'

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train) 
X_train = scaler.transform(X_train)

# %% [markdown]
# The few missing values we have are not conducive to a linear regression. I'll fill them with 0.

# %%
model = LinearRegression()
model.fit(X_train,y_train)
X_test =scaler.transform(X_test)
y_pred = model.predict(X_test)
print(y_pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 model = LinearRegression()
# ----> 2 model.fit(X_train,y_train)
#       3 X_test =scaler.transform(X_test)
#       4 y_pred = model.predict(X_test)
#
# File /opt/miniconda3/envs/ds_class/lib/python3.11/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File /opt/miniconda3/envs/ds_class/lib/python3.11/site-packages/sklearn/linear_model/_base.py:630, in LinearRegression.fit(self, X, y, sample_weight)
#     626 n_jobs_ = self.n_jobs
# ...
